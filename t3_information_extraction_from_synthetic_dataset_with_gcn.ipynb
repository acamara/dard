# %% [markdown]
# <div style="width: 100%; clear: both;">
# <div style="float: left; width: 50%;">
# <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
# </div>
# <div style="float: right; width: 50%;">
# <p style="margin: 0; padding-top: 22px; text-align:right;">M2.981 · TFM Àrea 4 · NLP & Text Mining</p>
# <p style="margin: 0; text-align:right;">2022 · Màster universitari en Ciència de dades (Data science)</p>
# <p style="margin: 0; text-align:right; padding-button: 100px;">Estudis d'Informàtica, Multimèdia i Telecomunicació</p>
# </div>
# </div>
# <div style="width:100%;">&nbsp;</div>
#
# <div class="row" style="padding-top: 50px;">
#     <div class="row" style="background: #494949;padding: 10px 20px; color: #FFF">
#         <div class="col-md-12">
#             <div style="text-align:left;"><b>Estudiant:</b> Albert Cámara Viñals</div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# # **T3 - Information Extraction from *synthetic invoice dataset* with *GCN* model**

# %% [markdown]
# ## **Information extraction**
#
# > Information extraction (IE) is the task of automatically extracting structured information from unstructured and/or semi-structured machine-readable documents and other electronically represented sources. In most of the cases this activity concerns processing images by means computer vision (CV) and processing human language texts by means of natural language processing (NLP).

# %% [markdown]
# **Dataset Folder structure**
#
# ```
# data/
#   provider/
#       provider-1.csv
#       provider-1.pdf
#       provider-1.tiff
#       provider-1.xml
#       ...
#   provider/
#       provider-1.csv
#       provider-1.pdf
#       provider-1.tiff
#       provider-1.xml
#       ...
# ```

# %%
# Load libraries
import cv2
import glob
import pandas as pd
import pickle
import math
import networkx as nx
import numpy as np
import os
import re
import seaborn as sns
import shutil

from IPython import display
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from xml.etree import ElementTree as ET

plt.style.use("ggplot")

# %matplotlib inline

# %% [markdown]
# ## Data Objects

# %% [markdown]
# ### Define some data models

# %%
# Class to store data attributes of Terms
class Term:
    def __init__(self, record):
        self.src = record.src
        self.num_pages = record.num_pages
        self.page_id = record.page_id
        self.page_width = record.page_width
        self.page_height = record.page_height
        self.id = record.id
        self.col = record.col
        self.row = record.row
        self.width = record.width
        self.height = record.height
        self.x1 = record.x1
        self.y1 = record.y1
        self.x2 = record.x2
        self.y2 = record.y2
        self.x3 = record.x3
        self.y3 = record.y3
        self.x4 = record.x4
        self.y4 = record.y4
        self.rdt = None 
        self.rdr = None
        self.rdb = None
        self.rdl = None
        self.content = record.contents
        self.content_masked = record.contents_masked
        self.correctclass = record.correctclass
        self.tag = record.tag
        self.description = record.description
    
    def set_rdt(self, rdt):
        self.rdt = rdt
        
    def get_rdt(self):
        return self.rdt
    
    def set_rdr(self, rdr):
        self.rdr = rdr
        
    def get_rdr(self):
        return self.rdr
    
    def set_rdb(self, rdb):
        self.rdb = rdb
        
    def get_rdb(self):
        return self.rdb
    
    def set_rdl(self, rdl):
        self.rdl = rdl
        
    def get_rdl(self):
        return self.rdl
     
    def show_term(self):
        print(self.src, self.num_pages, self.page_id, self.page_width, self.page_height, self.id, 
              self.col, self.row, self.width, self.height, self.x1, self.x2)
        
    def centroid(self):
        return  (self.x1 + self.width/2, self.y1 + self.height/2)

# %%
# Class to store document as a NetworkX
class NetworkData():
    
    def __init__(self, final_connections, G, df):
        self.final_connections = final_connections
        self.G = G
        self.df = df
        
    def get_processed_data(self):
        return self.df
    
    def get_relationships(self):
        return self.final_connections
    
    def get_networkx_graph(self):
        return self.G

# %% [markdown]
# ## Graph Modeling Algorithm
#
# #### Algorithm 1. Line Formattion

# %%
## Algorithm 1. Line Formattion

def extract_lines(df):

    # Sort words based on Top coordinate
    # Sort dataframe by top row and top column (0,0) (left, top)
    df.sort_values(by=['row', 'col'], inplace=True, ascending = [True, True])

    terms = {}
    lines = []  
    line = [Term(df.iloc[0])]

    # Form lines as group of words which obeys the following
    for i in range(1, len(df)):

        wa = Term(df.iloc[i - 1])
        wb = Term(df.iloc[i])

        terms[wa.id] = wa
        terms[wb.id] = wb

        wa_top = wa.y1
        wa_bottom = wa.y4

        wb_top = wb.y1
        wb_bottom = wb.y4

        # Form lines as group of words which obeys the following:
        if wa_top <= wb_bottom and wa_bottom >= wb_bottom:
            #print('Word in same line')
            line.extend([wb])

        else:
            #print('New line')
            if line:
                lines.append(line)
                line = [wb]

        if i == len(df)-1:
            lines.append(line)

    #  Sort words in each line based on Left coordinate
    for line in lines:
        line.sort(key=lambda term: term.x1)
    
    return lines, terms

# %% [markdown]
# #### Algorithm 2. Graph Modeling Algorithm

# %%
def check_terms_in_vertical_projection(c_term, lines, l_idx):
    #print('Search terms in vertical projection of:', c_term.content)
    projection_terms = []
    for i in range(l_idx + 1, len(lines)):
        for term in lines[i]:
            if c_term.x1 < term.x2 and c_term.x2 > term.x1:
                projection_terms.append(term)
    
    return projection_terms

# %%
def check_terms_in_horitzontal_projection(c_term, lines, l_idx, t_idx):
    #print('Search terms in horitzontal projection of:', c_term.content)
    projection_terms = []
    for i in range(l_idx, len(lines)):
        if i == l_idx: 
            for j in range(t_idx +1, len(lines[i])):
                term = lines[i][j]
                if c_term.y1 < term.y4 and c_term.y4 > term.y1:
                    projection_terms.append(term)
        else:
            for term in lines[i]:
                if c_term.y1 < term.y4 and c_term.y4 > term.y1 and c_term.x2 < term.x1:
                    projection_terms.append(term)
                    
    return projection_terms

# %%
## Algorithm 2. Graph Modeling Algorithm

def extract_relationships(lines, terms):
    
    relationships =  pd.DataFrame(columns=['n1', 'n2', 'direction'])

    # 1: Read words from each line starting from topmost line going towards bottommost line
    for l_idx, line in enumerate(lines):
        # 2: For each word, perform following:
        for t_idx, term in enumerate(line):

            # 2.1 Check words which are in vertical projection with it:
            terms_in_vertical_projection = check_terms_in_vertical_projection(term, lines, l_idx)

            if terms_in_vertical_projection:
                nnv_term = terms_in_vertical_projection[0]
                least_rdl = 1
                least_rdr = 1

                for pv_term in terms_in_vertical_projection: 
                    rdl = (pv_term.x2 - term.x1)/term.page_width
                    rdr = (pv_term.x1 - term.x2)/term.page_width

                    if abs(rdl) <= least_rdl and abs(rdr) <= least_rdr:
                        least_rdl = abs(rdl)
                        least_rdr = abs(rdr)
                        if pv_term.y1 <= nnv_term.y1:
                            nnv_term = pv_term

                if not ((relationships['n2'] == nnv_term.id) & (relationships['direction'] == 'vertical')).any():
                    rdb = (nnv_term.y1 - term.y3)/term.page_height
                    rdt = -rdb
                    term.set_rdb(rdb)
                    nnv_term.set_rdt(rdt)
                    terms.update({term.id: term, nnv_term.id: nnv_term})
                    relationship = {'n1': term.id,'n2': nnv_term.id, 'direction': 'vertical'}
                    relationships = relationships.append(relationship, ignore_index=True)

                #print('Term in vertical projection:', nnv_term.content)

            #print('') 

            terms_in_horitzontal_projection = check_terms_in_horitzontal_projection(term, lines, l_idx, t_idx)

            if terms_in_horitzontal_projection:
                nnh_term = terms_in_horitzontal_projection[0]
                least_rdt = 1
                least_rdb = 1

                for ph_term in terms_in_horitzontal_projection: 
                    rdt = (ph_term.y4 - term.y1)/term.page_height
                    rdb = (ph_term.y1 - term.y4)/term.page_height

                    if abs(rdt) <= least_rdt and abs(rdb) <= least_rdb:
                        least_rdt = abs(rdt)
                        least_rdb = abs(rdb)
                        if ph_term.x1 <= nnh_term.x1:
                            nnh_term = ph_term

                if not ((relationships['n2'] == nnh_term.id) & (relationships['direction'] == 'horitzontal')).any():
                    rdr = (nnh_term.x1 - term.x2)/term.page_width
                    rdl = -rdr
                    term.set_rdr(rdr)
                    nnh_term.set_rdl(rdl)
                    terms.update({term.id: term, nnh_term.id: nnh_term})
                    relationship = {'n1': term.id ,'n2': nnh_term.id, 'direction': 'horitzontal'}
                    relationships = relationships.append(relationship, ignore_index=True)
                    #print('Term in horitzontal projection:', nnh_term.content)

            #print('\n')
    return relationships

# %% [markdown]
# ## Functions & Utils

# %% [markdown]
# **Define some util functions**

# %%
# Function to draw bounding boxes in images
def draw_bouding_boxes(image, data, color):
    image = cv2.imread(image)

    for index, row in data.iterrows():
        cv2.rectangle(image, (row["x1"], row["y1"]), (row["x3"], row["y3"]), color)
           
    return image

# Function to draw bounding boxes and labels in images
def draw_bouding_boxes_and_labels(image, data, color, color_text, thickness, thickness_text):
    image = cv2.imread(image)

    for index, row in data.iterrows():
        cv2.rectangle(image, (row["x1"], row["y1"]), (row["x3"], row["y3"]), color, thickness)
        cv2.putText(image, row['tag'], (row["x1"], row["y1"]), cv2.FONT_HERSHEY_SIMPLEX, 0.4, color_text, thickness_text)
    
    return image

# Function to preview image
def show_image(image):   
    cv2.imshow('image', image)
    cv2.namedWindow("PREVIEW", cv2.WINDOW_NORMAL)   # Create window with freedom of dimensions
    image_resized = cv2.resize(image, (595, 842))   # Resize image
    cv2.imshow("PREVIEW", image_resized)            # Show image
    cv2.waitKey(0)                                  # Display the image infinitely until any keypress
        
def get_overlap_x(n1, n2):
    # overlap 
    x1 = max(n1.x1, n2.x1)
    x2 = min(n1.x2, n2.x2)
    
    return math.floor(x1 + (x2 - x1)/2)
    
def get_overlap_y(n1, n2):
    # overlap 
    y1 = max(n1.y1, n2.y1)
    y3 = min(n1.y3, n2.y3)
    
    return math.floor(y1 + (y3-y1)/2)

# Function to draw term relationships in image
def draw_relationships(image, df, relationships, color, thickness):
    
    data = df.copy()
    data.reset_index(inplace=True)
    data = data.rename(columns = {'index': 'id'})
    data = data.set_index('node_id')
    
    for index, relationship in relationships.iterrows():
        n1_id = relationship['n1']
        n2_id = relationship['n2']
        
        n1 = Term(data.loc[n1_id])
        n2 = Term(data.loc[n2_id])
                
        direction = relationship['direction']
                
        if direction == 'vertical':
            start_point = (get_overlap_x(n1, n2), n1.y3)
            end_point = (get_overlap_x(n1, n2), n2.y1)
            cv2.line(image, start_point, end_point, color, thickness)
        else:
            start_point = (n1.x2, get_overlap_y(n1, n2))
            end_point = (n2.x1, get_overlap_y(n1, n2))
            cv2.line(image, start_point, end_point, color, thickness)
    return image

# %% [markdown]
# **Define a function to extract features and relationships of a document**

# %%
# Define a function to extract features and relationships of a document
def process_file_to_get_features_and_relationships(filepath):
    dirname = os.path.dirname(filepath)
    filename = os.path.basename(filepath)
    basename = os.path.splitext(filename)[0]
    
    # Read dataframe
    df = pd.read_csv(filepath, sep=';')

    # Delete rows with null content and reset index
    df = df.dropna()
    df = df.reset_index(drop=True)

    # Create attributes
    df['alphabetic'] = df.apply(lambda x: x['contents_masked'].count('A'), axis=1)
    df['numeric'] = df.apply(lambda x: x['contents_masked'].count('N'), axis=1)
    df['symbolic'] = df.apply(lambda x: x['contents_masked'].count('S'), axis=1)
    df['feature'] = df.apply(lambda x: np.array([
        x['row']/x['page_height'], 
        x['col']/x['page_width'], 
        x['width']/x['page_width'], 
        x['height']/x['page_height'], 
        x['alphabetic']/len(x['contents']), 
        x['numeric']/len(x['contents']), 
        x['symbolic']/len(x['contents'])
    ], dtype=np.float32), axis=1)

    # Extract Lines
    lines, terms = extract_lines(df)

    # Extraxt relationships
    relationships = extract_relationships(lines, terms)
    
    # Prepend the node IDs that occur in each document with some kind of unique identifier for the specific document.
    df['node_id'] = df.apply(lambda x: basename.replace('-', '').lower() + '_' + str(x['id']), axis=1)
    relationships['n1'] = relationships.apply(lambda x: basename.replace('-', '').lower() + '_' + str(x['n1']), axis=1)
    relationships['n2'] = relationships.apply(lambda x: basename.replace('-', '').lower() + '_' + str(x['n2']), axis=1)
    
    # Update document Dataframe with new attributes
    df = df.set_index('id')

    # Assign new attributes to original dataframe
    for k, v in terms.items():
        df.at[k, 'rdt'] = v.get_rdt()
        df.at[k, 'rdr'] = v.get_rdr()
        df.at[k, 'rdb'] = v.get_rdb()
        df.at[k, 'rdl'] = v.get_rdl()
    
    # Create features
    df['f1'] = df.apply(lambda x: x['row']/x['page_height'], axis=1)
    df['f2'] = df.apply(lambda x: x['col']/x['page_width'], axis=1)
    df['f3'] = df.apply(lambda x: x['width']/x['page_width'], axis=1)
    df['f4'] = df.apply(lambda x: x['height']/x['page_height'], axis=1)
    df['f5'] = df.apply(lambda x: x['alphabetic']/len(x['contents']), axis=1)
    df['f6'] = df.apply(lambda x: x['numeric']/len(x['contents']), axis=1)
    df['f7'] = df.apply(lambda x: x['symbolic']/len(x['contents']), axis=1)
    df['f8'] = df.apply(lambda x: x['rdt'], axis=1)
    df['f9'] = df.apply(lambda x: x['rdr'], axis=1)
    df['f10'] = df.apply(lambda x: x['rdb'], axis=1)
    df['f11'] = df.apply(lambda x: x['rdl'], axis=1)
    
    # Create Graph
    # Add node relations
    G = nx.from_pandas_edgelist(relationships, "n1", "n2", ["direction"])
    
    # Add node features
    for node_id, node_data in G.nodes(data=True):
        node_data["feature"] = df[df['node_id'] == node_id]['feature'].values[0]

    # Store all info in a Object
    networkobject = NetworkData(relationships, G, df)
    
    return networkobject

# %% [markdown]
# ## Process a single file as example

# %%
# Define directories & FileNames
data_dir = './data/examples/'
filename = 'invoice-8.csv'
basename = 'invoice-8'

# %%
# Get features, relationships and NetworkX model of a Document
network = process_file_to_get_features_and_relationships(os.path.join(data_dir, filename))

# Get features of Terms of the document
df = network.get_processed_data()
print('Number of Terms:', len(df))

# Get relationships between Terms of the document
relationships = network.get_relationships()
print('Number of relationships:', len(relationships))

# Get NetworkX Graph of the document
G = network.get_networkx_graph()
labels = {d['node_id']: d['contents'] for d in df.to_dict(orient='records')}
edge_colors = ['red' if G[u][v]['direction'] == 'vertical' else 'green'  for u,v in G.edges]

# Show number of Nodes & Edges
print('Number of Nodes:', G.number_of_nodes())
print('Number of Edges:', G.number_of_edges())
# Out:
# Number of Terms: 140
# Number of relationships: 202
# Number of Nodes: 140
# Number of Edges: 202

# %%
# Draw bounding boxes and labels. Then preview image
image = draw_bouding_boxes_and_labels(os.path.join(data_dir, basename + '.tiff'), df, (0, 0, 255), (255,0, 0), 2, 1)

# Draw relationships
image = draw_relationships(image, df, relationships, (0, 255, 0), 1)

# Write image with bounding boxes, labels and relationships
cv2.imwrite(os.path.join(data_dir, basename + '-relationships.png'), image)

#show_image(image)

display.Image(os.path.join(data_dir, basename + '-relationships.png'))

# %%
# Preview the graph of the document
layout = nx.kamada_kawai_layout(G)
f = plt.figure(figsize=(50, 50))

ax = plt.gca()
ax.set_title('Graph form of ' + basename)

nx.draw(G, layout, labels=labels, with_labels=True, edge_color=edge_colors, node_size=7500, width=3, alpha=1, font_size=10, font_color="white")
plt.savefig(os.path.join(data_dir, basename + '-graph.jpg'), format="PNG", dpi=f.dpi)

# %% [markdown]
# ## Data preparation to load into GCN model (process all files)

# %% [markdown]
# **Define work directories**

# %%
# Define some directories
data_dir = './data/'
dataset_path = './data/synthetic_invoice/'
models_dir = './models/'
transformed_dataset_path = './data/synthetic_invoice/transformed/'

# %% [markdown]
# #### Load dataset

# %%
# Explore sample dataframe (document_type, file_name)
samples_list = pd.read_csv(os.path.join(dataset_path, 'samples_list.csv'), dtype=str, sep=';')
samples_list.head()
# Out:
#       type            file            image             pdf            gedi  \
# 0  invoice    amazon-1.csv    amazon-1.tiff    amazon-1.pdf    amazon-1.xml
# 1  invoice   amazon-10.csv   amazon-10.tiff   amazon-10.pdf   amazon-10.xml
# 2  invoice  amazon-100.csv  amazon-100.tiff  amazon-100.pdf  amazon-100.xml
# 3  invoice  amazon-101.csv  amazon-101.tiff  amazon-101.pdf  amazon-101.xml
# 4  invoice  amazon-102.csv  amazon-102.tiff  amazon-102.pdf  amazon-102.xml
#
#   provider words
# 0   amazon   169
# 1   amazon   183
# 2   amazon   195
# 3   amazon   173
# 4   amazon   205

# %% [markdown]
# #### Split dataset into train-val-test sets

# %%
# Get list of providers
providers =  samples_list['provider'].values

# Split dataset into train-test sets preserving the representation of each provider
train_samples, test_samples = train_test_split(samples_list, test_size=0.20, random_state=0, stratify=providers)

# Get list of providers
providers =  train_samples['provider'].values

# Split dataset into train-test sets preserving the representation of each provider
train_samples, val_samples = train_test_split(train_samples, test_size=0.50, random_state=0, stratify=providers)

# Show sets size
print('Train size:', train_samples.shape)
print('Validation size:', val_samples.shape)
print('Test size:', test_samples.shape)
# Out:
# Train size: (700, 7)
# Validation size: (700, 7)
# Test size: (350, 7)

# %% [markdown]
# **Process all documents in Train Set**

# %%
# Get all documents as a graph representaion or model
networks_train = [process_file_to_get_features_and_relationships(os.path.join(transformed_dataset_path, row['provider'], row['file'])) for idx, row in train_samples.iterrows()]

# %%
file_to_store = open(os.path.join(dataset_path, 'train_documents_networkx_7_features.pickle'), "wb")
pickle.dump(networks_train, file_to_store)
file_to_store.close()

# %%
# Union of multiple documents graphs 
U_train = nx.union_all([network.G for network in networks_train])

print(U_train)
# Out:
# Graph with 136077 nodes and 202702 edges

# %%
file_to_store = open(os.path.join(dataset_path, 'train_documents_union_networkx_7_features.pickle'), "wb")
pickle.dump(U_train, file_to_store)
file_to_store.close()

# %% [markdown]
# **Process all documents in Validation Set**

# %%
# Make the same processing for Validation Set
networks_val = [process_file_to_get_features_and_relationships(os.path.join(transformed_dataset_path, row['provider'], row['file'])) for idx, row in val_samples.iterrows()]

networks_val_file = open(os.path.join(dataset_path, 'val_documents_networkx_7_features.pickle'), "wb")
pickle.dump(networks_val, networks_val_file)
networks_val_file.close()

# Union of multiple documents graphs 
U_val = nx.union_all([network.G for network in networks_val])

print(U_val)

file_to_store = open(os.path.join(dataset_path, 'val_documents_union_networkx_7_features.pickle'), "wb")
pickle.dump(U_val, file_to_store)
file_to_store.close()
# Out:
# Graph with 134601 nodes and 200308 edges

# %% [markdown]
# **Process all documents in Test Set**

# %%
# Make the same processing for Test set
networks_test = [process_file_to_get_features_and_relationships(os.path.join(transformed_dataset_path, row['provider'], row['file'])) for idx, row in test_samples.iterrows()]
networks_test_file = open(os.path.join(dataset_path, 'test_documents_networkx_7_features.pickle'), "wb")
pickle.dump(networks_test, networks_test_file)
networks_test_file.close()

# Union of multiple documents graphs 
U_test = nx.union_all([network.G for network in networks_test])

print(U_test)

file_to_store = open(os.path.join(dataset_path, 'test_documents_union_networkx_7_features.pickle'), "wb")
pickle.dump(U_test, file_to_store)
file_to_store.close()
# Out:
# Graph with 68079 nodes and 101439 edges

# %%
# Union of multiple documents graphs on Train, Validation & Set
U = nx.union_all([U_train, U_val, U_test])

print(U)

# Save union of all documents graphs as a Networkx on Train, Validation & Test Set to a file
nx_file = open(os.path.join(dataset_path, 'documents_union_networkx_7_features.pickle'), "wb")
pickle.dump(U, nx_file)
nx_file.close()
# Out:
# Graph with 338757 nodes and 504449 edges

# %% [markdown]
# ## Modeling

# %% [markdown]
# **Prepare data to load into StellarGraph model**

# %%
import tensorflow as tf
from stellargraph import StellarGraph as sg
from stellargraph import utils
from stellargraph.mapper import FullBatchNodeGenerator
from stellargraph.layer import GCN
from tensorflow import keras
from tensorflow.keras import layers, losses, metrics, Model, regularizers
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

tf.debugging.set_log_device_placement(True)

tf.__version__
# Out:
# Num GPUs Available:  1
# '2.8.0'

# %%
networkx_file = open(os.path.join(dataset_path, 'documents_union_networkx_7_features.pickle'), "rb")
U = pickle.load(networkx_file)
networkx_file.close()

print(U)
# Out:
# Graph with 338757 nodes and 504449 edges

# %%
# Load data directly from Networkx into StellarGraph
G_sg = sg.from_networkx(U, node_features="feature")

# Show graph 
print(G_sg.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 338757, Edges: 504449
#
#  Node types:
#   default: [338757]
#     Features: float32 vector, length 7
#     Edge types: default-default->default
#
#  Edge types:
#     default-default->default: [504449]
#         Weights: all 1 (default)
#         Features: none

# %%
# Read all individual documents graph Networkx of Train Set
nx_train_file = open(os.path.join(dataset_path, 'train_documents_networkx_7_features.pickle'), "rb")
nx_train = pickle.load(nx_train_file)
nx_train_file.close()

print('Number of document networks on Train Set:', len(nx_train))
# Out:
# Number of document networks on Train Set: 700

# %%
# Get labels for each node on Train Set

# Get labels of NetworkData
labels_train = [network.df[['node_id', 'tag']] for network in nx_train]

# Create a Dataframe of Nodes, Labels
tagged_data_train = pd.concat(labels_train, sort=False)
tagged_data_train.rename(columns = {'tag': 'node_target'}, inplace = True)

train = tagged_data_train

# Show number of Labels
print('Number of labels on Train Set:', len(tagged_data_train))
# Out:
# Number of labels on Train Set: 136077

# %%
# Compute frequency on each one of classes for class attribute 'node_target'
tagged_data_train["node_target"].value_counts()
# Out:
# OTHER                              73791
# PRODUCT_DESCRIPTION                11654
# SUPPLIER_ADDRESS                    7134
# BILLING_ADDRESS                     4634
# SHIPPING_ADDRESS                    4520
# INVOICE_DATE                        2914
# SUPPLIER_VAT                        2822
# SUPPLIER_NAME                       2683
# PRODUCT_TOTAL_PRICE_WITHOUT_TAX     2504
# SUPPLIER_CONTACT_NUMBER             2388
# UNIT_PRICE                          2305
# SUPPLIER_FAX_NUMBER                 2039
# QUANTITY                            1787
# SHIPPING_NAME                       1656
# BILLING_NAME                        1655
# TOTAL_AMOUNT                        1599
# TAX_RATE                            1418
# TOTAL_TAX                           1249
# SNO                                 1220
# SUPPLIER_SIRET                       982
# TOTAL_WITHOUT_TAX                    979
# INVOICE_NUMBER                       937
# ORDER_NUMBER                         700
# SUPPLIER_ID                          602
# PRODUCT_TOTAL                        558
# PAYMENT_MODE                         429
# PRODUCT_TOTAL_PRICE_WITH_TAX         418
# CLIENT_NUMBER                        300
# IMAGE                                200
# Name: node_target, dtype: int64

# %%
# Create barchart for class attribute 'TAG'
plt.figure(figsize=(12, 7))
g1 = sns.countplot(x="node_target", data=tagged_data_train)
plt.xlabel('Atribut/entitat')
plt.ylabel('Freqüència')
plt.xticks(rotation='vertical')

obs = len(tagged_data_train);

# Add tags to graph
#for p, label in zip(g1.patches, tagged_data_train["node_target"].value_counts().index):
#    g1.annotate(' (' + str(round(p.get_height()/obs*100, 2)) + '%)' , (p.get_x() + 0.05, p.get_height() + 1500))

# %%
# Read all individual documents graph Networkx of Validation Set
nx_val_file = open(os.path.join(dataset_path, 'val_documents_networkx_7_features.pickle'), "rb")
nx_val = pickle.load(nx_val_file)
nx_val_file.close()
print('Number of document networks on Validation Set:', len(nx_val))

# Get labels for each node on Validation Set

# Get labels of NetworkData
labels_val = [network.df[['node_id', 'tag']] for network in nx_val]
tagged_data_val = pd.concat(labels_val, sort=False)
tagged_data_val.rename(columns = {'tag':'node_target'}, inplace = True)

val = tagged_data_val

print('Number of labels on Validation Set:', len(tagged_data_val))
# Out:
# Number of document networks on Validation Set: 700
# Number of labels on Validation Set: 134601

# %%
# Read all individual documents graph Networkx of Test Set
nx_test_file = open(os.path.join(dataset_path, 'test_documents_networkx_7_features.pickle'), "rb")
nx_test = pickle.load(nx_test_file)
nx_test_file.close()
print('Number of document networks on Test Set:', len(nx_test))

# Get labels for each node on Test Set

# Get labels of NetworkData
labels_test = [network.df[['node_id', 'tag']] for network in nx_test]
tagged_data_test = pd.concat(labels_test, sort=False)
tagged_data_test.rename(columns = {'tag':'node_target'}, inplace = True)

test = tagged_data_test

print('Number of labels on Test Set:', len(tagged_data_test))
# Out:
# Number of document networks on Test Set: 350
# Number of labels on Test Set: 68079

# %%
# Encoding the targets
target_encoding = preprocessing.LabelBinarizer()
train_targets = target_encoding.fit_transform(train.node_target)
val_targets = target_encoding.fit_transform(val.node_target)
test_targets = target_encoding.fit_transform(test.node_target)

# Examine size
print('Train', train.shape, train_targets.shape)
print('Validation', val.shape, val_targets.shape)
print('Test:', test.shape, test_targets.shape)
# Out:
# Train (136077, 2) (136077, 29)
# Validation (134601, 2) (134601, 29)
# Test: (68079, 2) (68079, 29)

# %%
# Create a generator function to generate batches of nodes given the Stellar Network Graph.
generator = FullBatchNodeGenerator(G_sg, method="gcn")
# Out:
# Using GCN (local pooling) filters...

# %%
# Call the flow function and pass the target label and the nodes to get an object that can be used as a Keras data generator.
train_gen = generator.flow(train.node_id, train_targets)
val_gen = generator.flow(val.node_id, val_targets)

# %% [markdown]
# **Build model**

# %%
# Model Formation
# Four layers of GCN

def build_gcn_model(learning_rate):  
    gcn = GCN(layer_sizes=[16, 32, 64, 128], activations=["relu", "relu", "relu", "relu"], generator=generator, dropout=0.5)

    # expose in and out to create keras model
    x_inp, x_out = gcn.in_out_tensors()

    # usual output layer
    predictions = layers.Dense(units=train_targets.shape[1], activation = "softmax")(x_out)

    # define model
    model = Model(inputs=x_inp, outputs=predictions)

    # compile model
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss=losses.categorical_crossentropy, metrics=['accuracy'])
    
    return model
    
# Build the GCN model
gcn_model = build_gcn_model(0.01)

# %%
# Validate model blocks
print(gcn_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(1, 338757, 7)]     0           []
#
#  input_3 (InputLayer)           [(1, None, 2)]       0           []
#
#  input_4 (InputLayer)           [(1, None)]          0           []
#
#  dropout (Dropout)              (1, 338757, 7)       0           ['input_1[0][0]']
#
#  squeezed_sparse_conversion (Sq  (338757, 338757)    0           ['input_3[0][0]',
#  ueezedSparseConversion)                                          'input_4[0][0]']
#
#  graph_convolution (GraphConvol  (1, None, 16)       128         ['dropout[0][0]',
#  ution)                                                           'squeezed_sparse_conversion[0][0
#                                                                  ]']
#
#  dropout_1 (Dropout)            (1, None, 16)        0           ['graph_convolution[0][0]']
#
#  graph_convolution_1 (GraphConv  (1, None, 32)       544         ['dropout_1[0][0]',
#  olution)                                                         'squeezed_sparse_conversion[0][0
#                                                                  ]']
#
#  dropout_2 (Dropout)            (1, None, 32)        0           ['graph_convolution_1[0][0]']
#
#  graph_convolution_2 (GraphConv  (1, None, 64)       2112        ['dropout_2[0][0]',
#  olution)                                                         'squeezed_sparse_conversion[0][0
#                                                                  ]']
#
#  dropout_3 (Dropout)            (1, None, 64)        0           ['graph_convolution_2[0][0]']
#
#  graph_convolution_3 (GraphConv  (1, None, 128)      8320        ['dropout_3[0][0]',
#  olution)                                                         'squeezed_sparse_conversion[0][0
#                                                                  ]']
#
#  input_2 (InputLayer)           [(1, None)]          0           []
#
#  gather_indices (GatherIndices)  (1, None, 128)      0           ['graph_convolution_3[0][0]',
#                                                                   'input_2[0][0]']
#
#  dense (Dense)                  (1, None, 29)        3741        ['gather_indices[0][0]']
#
# ==================================================================================================
# Total params: 14,845
# Trainable params: 14,845
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
from keras.utils.vis_utils import plot_model

plot_model(gcn_model, to_file=os.path.join(models_dir, 'gcn_model_7_features_plot.png'), show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## Training and Model Performance Plots

# %%
# Fit the model and check the result
epochs = 350

gcn_early_stopping = EarlyStopping(monitor='val_accuracy', patience=75, restore_best_weights=True, verbose=1)

gcn_history = gcn_model.fit(train_gen, epochs=epochs, validation_data=val_gen, shuffle=False, verbose=1, callbacks=[gcn_early_stopping])
# Out:
# Epoch 1/350
# 1/1 [==============================] - 3s 3s/step - loss: 3.3202 - accuracy: 0.0307 - val_loss: 2.9205 - val_accuracy: 0.5456
# Epoch 2/350
# 1/1 [==============================] - 0s 116ms/step - loss: 2.8886 - accuracy: 0.5423 - val_loss: 2.3927 - val_accuracy: 0.5456
# Epoch 3/350
# 1/1 [==============================] - 0s 117ms/step - loss: 2.3709 - accuracy: 0.5423 - val_loss: 2.1991 - val_accuracy: 0.5456
# Epoch 4/350
# 1/1 [==============================] - 0s 115ms/step - loss: 2.3681 - accuracy: 0.5423 - val_loss: 2.1982 - val_accuracy: 0.5456
# Epoch 5/350
# 1/1 [==============================] - 0s 121ms/step - loss: 2.3707 - accuracy: 0.5423 - val_loss: 2.0905 - val_accuracy: 0.5456
# Epoch 6/350
# 1/1 [==============================] - 0s 118ms/step - loss: 2.1991 - accuracy: 0.5423 - val_loss: 2.1063 - val_accuracy: 0.5456
# Epoch 7/350
# 1/1 [==============================] - 0s 116ms/step - loss: 2.1540 - accuracy: 0.5423 - val_loss: 2.1703 - val_accuracy: 0.5456
# Epoch 8/350
# 1/1 [==============================] - 0s 115ms/step - loss: 2.1852 - accuracy: 0.5423 - val_loss: 2.1909 - val_accuracy: 0.5456
# Epoch 9/350
# 1/1 [==============================] - 0s 115ms/step - loss: 2.1986 - accuracy: 0.5423 - val_loss: 2.1541 - val_accuracy: 0.5456
# Epoch 10/350
# 1/1 [==============================] - 0s 114ms/step - loss: 2.1714 - accuracy: 0.5423 - val_loss: 2.0839 - val_accuracy: 0.5456
# Epoch 11/350
# 1/1 [==============================] - 0s 114ms/step - loss: 2.1222 - accuracy: 0.5423 - val_loss: 2.0245 - val_accuracy: 0.5456
# Epoch 12/350
# 1/1 [==============================] - 0s 119ms/step - loss: 2.0923 - accuracy: 0.5423 - val_loss: 2.0133 - val_accuracy: 0.5456
# Epoch 13/350
# 1/1 [==============================] - 0s 115ms/step - loss: 2.1090 - accuracy: 0.5423 - val_loss: 2.0267 - val_accuracy: 0.5456
# Epoch 14/350
# 1/1 [==============================] - 0s 112ms/step - loss: 2.1299 - accuracy: 0.5423 - val_loss: 2.0170 - val_accuracy: 0.5456
# Epoch 15/350
# 1/1 [==============================] - 0s 114ms/step - loss: 2.1209 - accuracy: 0.5423 - val_loss: 1.9960 - val_accuracy: 0.5456
# Epoch 16/350
# 1/1 [==============================] - 0s 117ms/step - loss: 2.0775 - accuracy: 0.5423 - val_loss: 1.9964 - val_accuracy: 0.5456
# Epoch 17/350
# 1/1 [==============================] - 0s 116ms/step - loss: 2.0626 - accuracy: 0.5423 - val_loss: 2.0165 - val_accuracy: 0.5456
# Epoch 18/350
# 1/1 [==============================] - 0s 114ms/step - loss: 2.0659 - accuracy: 0.5423 - val_loss: 2.0336 - val_accuracy: 0.5456
# Epoch 19/350
# 1/1 [==============================] - 0s 118ms/step - loss: 2.0739 - accuracy: 0.5423 - val_loss: 2.0322 - val_accuracy: 0.5456
# Epoch 20/350
# 1/1 [==============================] - 0s 126ms/step - loss: 2.0695 - accuracy: 0.5423 - val_loss: 2.0106 - val_accuracy: 0.5456
# Epoch 21/350
# 1/1 [==============================] - 0s 125ms/step - loss: 2.0535 - accuracy: 0.5423 - val_loss: 1.9790 - val_accuracy: 0.5456
# Epoch 22/350
# 1/1 [==============================] - 0s 114ms/step - loss: 2.0347 - accuracy: 0.5423 - val_loss: 1.9561 - val_accuracy: 0.5456
# Epoch 23/350
# 1/1 [==============================] - 0s 129ms/step - loss: 2.0238 - accuracy: 0.5423 - val_loss: 1.9502 - val_accuracy: 0.5456
# Epoch 24/350
# 1/1 [==============================] - 0s 115ms/step - loss: 2.0317 - accuracy: 0.5423 - val_loss: 1.9447 - val_accuracy: 0.5456
# Epoch 25/350
# 1/1 [==============================] - 0s 116ms/step - loss: 2.0337 - accuracy: 0.5423 - val_loss: 1.9338 - val_accuracy: 0.5456
# Epoch 26/350
# 1/1 [==============================] - 0s 114ms/step - loss: 2.0141 - accuracy: 0.5423 - val_loss: 1.9325 - val_accuracy: 0.5456
# Epoch 27/350
# 1/1 [==============================] - 0s 105ms/step - loss: 1.9997 - accuracy: 0.5423 - val_loss: 1.9419 - val_accuracy: 0.5456
# Epoch 28/350
# 1/1 [==============================] - 0s 123ms/step - loss: 1.9971 - accuracy: 0.5423 - val_loss: 1.9464 - val_accuracy: 0.5456
# Epoch 29/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.9947 - accuracy: 0.5423 - val_loss: 1.9358 - val_accuracy: 0.5456
# Epoch 30/350
# 1/1 [==============================] - 0s 114ms/step - loss: 1.9886 - accuracy: 0.5423 - val_loss: 1.9128 - val_accuracy: 0.5456
# Epoch 31/350
# 1/1 [==============================] - 0s 112ms/step - loss: 1.9731 - accuracy: 0.5423 - val_loss: 1.8893 - val_accuracy: 0.5456
# Epoch 32/350
# 1/1 [==============================] - 0s 123ms/step - loss: 1.9640 - accuracy: 0.5423 - val_loss: 1.8730 - val_accuracy: 0.5456
# Epoch 33/350
# 1/1 [==============================] - 0s 109ms/step - loss: 1.9595 - accuracy: 0.5423 - val_loss: 1.8614 - val_accuracy: 0.5456
# Epoch 34/350
# 1/1 [==============================] - 0s 122ms/step - loss: 1.9570 - accuracy: 0.5423 - val_loss: 1.8533 - val_accuracy: 0.5456
# Epoch 35/350
# 1/1 [==============================] - 0s 115ms/step - loss: 1.9424 - accuracy: 0.5423 - val_loss: 1.8539 - val_accuracy: 0.5456
# Epoch 36/350
# 1/1 [==============================] - 0s 123ms/step - loss: 1.9335 - accuracy: 0.5423 - val_loss: 1.8566 - val_accuracy: 0.5456
# Epoch 37/350
# 1/1 [==============================] - 0s 133ms/step - loss: 1.9309 - accuracy: 0.5423 - val_loss: 1.8503 - val_accuracy: 0.5456
# Epoch 38/350
# 1/1 [==============================] - 0s 112ms/step - loss: 1.9254 - accuracy: 0.5423 - val_loss: 1.8341 - val_accuracy: 0.5456
# Epoch 39/350
# 1/1 [==============================] - 0s 122ms/step - loss: 1.9190 - accuracy: 0.5423 - val_loss: 1.8157 - val_accuracy: 0.5456
# Epoch 40/350
# 1/1 [==============================] - 0s 102ms/step - loss: 1.9094 - accuracy: 0.5423 - val_loss: 1.8010 - val_accuracy: 0.5456
# Epoch 41/350
# 1/1 [==============================] - 0s 114ms/step - loss: 1.9079 - accuracy: 0.5423 - val_loss: 1.7920 - val_accuracy: 0.5456
# Epoch 42/350
# 1/1 [==============================] - 0s 116ms/step - loss: 1.9023 - accuracy: 0.5423 - val_loss: 1.7917 - val_accuracy: 0.5456
# Epoch 43/350
# 1/1 [==============================] - 0s 116ms/step - loss: 1.8938 - accuracy: 0.5423 - val_loss: 1.7959 - val_accuracy: 0.5456
# Epoch 44/350
# 1/1 [==============================] - 0s 116ms/step - loss: 1.8927 - accuracy: 0.5423 - val_loss: 1.7916 - val_accuracy: 0.5456
# Epoch 45/350
# 1/1 [==============================] - 0s 110ms/step - loss: 1.8903 - accuracy: 0.5423 - val_loss: 1.7768 - val_accuracy: 0.5456
# Epoch 46/350
# 1/1 [==============================] - 0s 101ms/step - loss: 1.8826 - accuracy: 0.5423 - val_loss: 1.7602 - val_accuracy: 0.5456
# Epoch 47/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.8748 - accuracy: 0.5423 - val_loss: 1.7476 - val_accuracy: 0.5456
# Epoch 48/350
# 1/1 [==============================] - 0s 115ms/step - loss: 1.8763 - accuracy: 0.5423 - val_loss: 1.7423 - val_accuracy: 0.5456
# Epoch 49/350
# 1/1 [==============================] - 0s 114ms/step - loss: 1.8643 - accuracy: 0.5423 - val_loss: 1.7434 - val_accuracy: 0.5456
# Epoch 50/350
# 1/1 [==============================] - 0s 103ms/step - loss: 1.8562 - accuracy: 0.5423 - val_loss: 1.7401 - val_accuracy: 0.5456
# Epoch 51/350
# 1/1 [==============================] - 0s 114ms/step - loss: 1.8546 - accuracy: 0.5423 - val_loss: 1.7264 - val_accuracy: 0.5456
# Epoch 52/350
# 1/1 [==============================] - 0s 116ms/step - loss: 1.8463 - accuracy: 0.5423 - val_loss: 1.7097 - val_accuracy: 0.5456
# Epoch 53/350
# 1/1 [==============================] - 0s 124ms/step - loss: 1.8463 - accuracy: 0.5423 - val_loss: 1.6979 - val_accuracy: 0.5456
# Epoch 54/350
# 1/1 [==============================] - 0s 116ms/step - loss: 1.8394 - accuracy: 0.5423 - val_loss: 1.6918 - val_accuracy: 0.5456
# Epoch 55/350
# 1/1 [==============================] - 0s 106ms/step - loss: 1.8282 - accuracy: 0.5422 - val_loss: 1.6887 - val_accuracy: 0.5456
# Epoch 56/350
# 1/1 [==============================] - 0s 125ms/step - loss: 1.8245 - accuracy: 0.5421 - val_loss: 1.6818 - val_accuracy: 0.5456
# Epoch 57/350
# 1/1 [==============================] - 0s 108ms/step - loss: 1.8179 - accuracy: 0.5422 - val_loss: 1.6674 - val_accuracy: 0.5456
# Epoch 58/350
# 1/1 [==============================] - 0s 117ms/step - loss: 1.8121 - accuracy: 0.5423 - val_loss: 1.6540 - val_accuracy: 0.5456
# Epoch 59/350
# 1/1 [==============================] - 0s 125ms/step - loss: 1.8061 - accuracy: 0.5422 - val_loss: 1.6452 - val_accuracy: 0.5456
# Epoch 60/350
# 1/1 [==============================] - 0s 104ms/step - loss: 1.7985 - accuracy: 0.5423 - val_loss: 1.6374 - val_accuracy: 0.5456
# Epoch 61/350
# 1/1 [==============================] - 0s 122ms/step - loss: 1.7900 - accuracy: 0.5424 - val_loss: 1.6291 - val_accuracy: 0.5456
# Epoch 62/350
# 1/1 [==============================] - 0s 127ms/step - loss: 1.7879 - accuracy: 0.5423 - val_loss: 1.6177 - val_accuracy: 0.5456
# Epoch 63/350
# 1/1 [==============================] - 0s 116ms/step - loss: 1.7825 - accuracy: 0.5425 - val_loss: 1.6045 - val_accuracy: 0.5456
# Epoch 64/350
# 1/1 [==============================] - 0s 116ms/step - loss: 1.7741 - accuracy: 0.5424 - val_loss: 1.5912 - val_accuracy: 0.5456
# Epoch 65/350
# 1/1 [==============================] - 0s 123ms/step - loss: 1.7726 - accuracy: 0.5427 - val_loss: 1.5819 - val_accuracy: 0.5458
# Epoch 66/350
# 1/1 [==============================] - 0s 128ms/step - loss: 1.7628 - accuracy: 0.5425 - val_loss: 1.5738 - val_accuracy: 0.5462
# Epoch 67/350
# 1/1 [==============================] - 0s 109ms/step - loss: 1.7537 - accuracy: 0.5426 - val_loss: 1.5678 - val_accuracy: 0.5465
# Epoch 68/350
# 1/1 [==============================] - 0s 114ms/step - loss: 1.7523 - accuracy: 0.5428 - val_loss: 1.5607 - val_accuracy: 0.5469
# Epoch 69/350
# 1/1 [==============================] - 0s 151ms/step - loss: 1.7451 - accuracy: 0.5422 - val_loss: 1.5494 - val_accuracy: 0.5473
# Epoch 70/350
# 1/1 [==============================] - 0s 121ms/step - loss: 1.7420 - accuracy: 0.5415 - val_loss: 1.5413 - val_accuracy: 0.5471
# Epoch 71/350
# 1/1 [==============================] - 0s 114ms/step - loss: 1.7301 - accuracy: 0.5422 - val_loss: 1.5351 - val_accuracy: 0.5469
# Epoch 72/350
# 1/1 [==============================] - 0s 135ms/step - loss: 1.7287 - accuracy: 0.5423 - val_loss: 1.5324 - val_accuracy: 0.5470
# Epoch 73/350
# 1/1 [==============================] - 0s 130ms/step - loss: 1.7221 - accuracy: 0.5419 - val_loss: 1.5262 - val_accuracy: 0.5476
# Epoch 74/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.7159 - accuracy: 0.5418 - val_loss: 1.5155 - val_accuracy: 0.5490
# Epoch 75/350
# 1/1 [==============================] - 0s 122ms/step - loss: 1.7104 - accuracy: 0.5421 - val_loss: 1.5090 - val_accuracy: 0.5517
# Epoch 76/350
# 1/1 [==============================] - 0s 135ms/step - loss: 1.7095 - accuracy: 0.5428 - val_loss: 1.5048 - val_accuracy: 0.5543
# Epoch 77/350
# 1/1 [==============================] - 0s 120ms/step - loss: 1.7028 - accuracy: 0.5425 - val_loss: 1.4967 - val_accuracy: 0.5545
# Epoch 78/350
# 1/1 [==============================] - 0s 127ms/step - loss: 1.7011 - accuracy: 0.5421 - val_loss: 1.4854 - val_accuracy: 0.5550
# Epoch 79/350
# 1/1 [==============================] - 0s 118ms/step - loss: 1.6930 - accuracy: 0.5417 - val_loss: 1.4773 - val_accuracy: 0.5546
# Epoch 80/350
# 1/1 [==============================] - 0s 114ms/step - loss: 1.6893 - accuracy: 0.5424 - val_loss: 1.4728 - val_accuracy: 0.5546
# Epoch 81/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.6821 - accuracy: 0.5423 - val_loss: 1.4655 - val_accuracy: 0.5552
# Epoch 82/350
# 1/1 [==============================] - 0s 112ms/step - loss: 1.6814 - accuracy: 0.5415 - val_loss: 1.4576 - val_accuracy: 0.5596
# Epoch 83/350
# 1/1 [==============================] - 0s 114ms/step - loss: 1.6774 - accuracy: 0.5414 - val_loss: 1.4494 - val_accuracy: 0.5625
# Epoch 84/350
# 1/1 [==============================] - 0s 122ms/step - loss: 1.6732 - accuracy: 0.5422 - val_loss: 1.4462 - val_accuracy: 0.5606
# Epoch 85/350
# 1/1 [==============================] - 0s 114ms/step - loss: 1.6711 - accuracy: 0.5414 - val_loss: 1.4390 - val_accuracy: 0.5608
# Epoch 86/350
# 1/1 [==============================] - 0s 130ms/step - loss: 1.6650 - accuracy: 0.5432 - val_loss: 1.4322 - val_accuracy: 0.5607
# Epoch 87/350
# 1/1 [==============================] - 0s 119ms/step - loss: 1.6622 - accuracy: 0.5414 - val_loss: 1.4339 - val_accuracy: 0.5620
# Epoch 88/350
# 1/1 [==============================] - 0s 111ms/step - loss: 1.6597 - accuracy: 0.5419 - val_loss: 1.4296 - val_accuracy: 0.5616
# Epoch 89/350
# 1/1 [==============================] - 0s 120ms/step - loss: 1.6541 - accuracy: 0.5439 - val_loss: 1.4180 - val_accuracy: 0.5624
# Epoch 90/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.6495 - accuracy: 0.5435 - val_loss: 1.4117 - val_accuracy: 0.5620
# Epoch 91/350
# 1/1 [==============================] - 0s 130ms/step - loss: 1.6445 - accuracy: 0.5447 - val_loss: 1.4171 - val_accuracy: 0.5606
# Epoch 92/350
# 1/1 [==============================] - 0s 116ms/step - loss: 1.6467 - accuracy: 0.5421 - val_loss: 1.4121 - val_accuracy: 0.5610
# Epoch 93/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.6433 - accuracy: 0.5432 - val_loss: 1.4005 - val_accuracy: 0.5625
# Epoch 94/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.6400 - accuracy: 0.5439 - val_loss: 1.3957 - val_accuracy: 0.5633
# Epoch 95/350
# 1/1 [==============================] - 0s 114ms/step - loss: 1.6351 - accuracy: 0.5439 - val_loss: 1.4012 - val_accuracy: 0.5636
# Epoch 96/350
# 1/1 [==============================] - 0s 111ms/step - loss: 1.6348 - accuracy: 0.5444 - val_loss: 1.3993 - val_accuracy: 0.5637
# Epoch 97/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.6312 - accuracy: 0.5435 - val_loss: 1.3866 - val_accuracy: 0.5650
# Epoch 98/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.6227 - accuracy: 0.5439 - val_loss: 1.3808 - val_accuracy: 0.5638
# Epoch 99/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.6218 - accuracy: 0.5432 - val_loss: 1.3850 - val_accuracy: 0.5638
# Epoch 100/350
# 1/1 [==============================] - 0s 109ms/step - loss: 1.6290 - accuracy: 0.5432 - val_loss: 1.3891 - val_accuracy: 0.5629
# Epoch 101/350
# 1/1 [==============================] - 0s 128ms/step - loss: 1.6211 - accuracy: 0.5436 - val_loss: 1.3822 - val_accuracy: 0.5644
# Epoch 102/350
# 1/1 [==============================] - 0s 123ms/step - loss: 1.6239 - accuracy: 0.5432 - val_loss: 1.3720 - val_accuracy: 0.5661
# Epoch 103/350
# 1/1 [==============================] - 0s 140ms/step - loss: 1.6242 - accuracy: 0.5436 - val_loss: 1.3731 - val_accuracy: 0.5663
# Epoch 104/350
# 1/1 [==============================] - 0s 140ms/step - loss: 1.6180 - accuracy: 0.5453 - val_loss: 1.3801 - val_accuracy: 0.5662
# Epoch 105/350
# 1/1 [==============================] - 0s 132ms/step - loss: 1.6093 - accuracy: 0.5454 - val_loss: 1.3773 - val_accuracy: 0.5675
# Epoch 106/350
# 1/1 [==============================] - 0s 125ms/step - loss: 1.6161 - accuracy: 0.5454 - val_loss: 1.3663 - val_accuracy: 0.5677
# Epoch 107/350
# 1/1 [==============================] - 0s 105ms/step - loss: 1.6136 - accuracy: 0.5451 - val_loss: 1.3639 - val_accuracy: 0.5675
# Epoch 108/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.6112 - accuracy: 0.5449 - val_loss: 1.3664 - val_accuracy: 0.5684
# Epoch 109/350
# 1/1 [==============================] - 0s 115ms/step - loss: 1.6054 - accuracy: 0.5455 - val_loss: 1.3696 - val_accuracy: 0.5714
# Epoch 110/350
# 1/1 [==============================] - 0s 126ms/step - loss: 1.6082 - accuracy: 0.5454 - val_loss: 1.3646 - val_accuracy: 0.5729
# Epoch 111/350
# 1/1 [==============================] - 0s 138ms/step - loss: 1.6079 - accuracy: 0.5459 - val_loss: 1.3573 - val_accuracy: 0.5710
# Epoch 112/350
# 1/1 [==============================] - 0s 137ms/step - loss: 1.6093 - accuracy: 0.5461 - val_loss: 1.3581 - val_accuracy: 0.5712
# Epoch 113/350
# 1/1 [==============================] - 0s 126ms/step - loss: 1.5996 - accuracy: 0.5467 - val_loss: 1.3614 - val_accuracy: 0.5721
# Epoch 114/350
# 1/1 [==============================] - 0s 109ms/step - loss: 1.6039 - accuracy: 0.5456 - val_loss: 1.3598 - val_accuracy: 0.5723
# Epoch 115/350
# 1/1 [==============================] - 0s 127ms/step - loss: 1.5990 - accuracy: 0.5467 - val_loss: 1.3539 - val_accuracy: 0.5719
# Epoch 116/350
# 1/1 [==============================] - 0s 117ms/step - loss: 1.5968 - accuracy: 0.5457 - val_loss: 1.3536 - val_accuracy: 0.5739
# Epoch 117/350
# 1/1 [==============================] - 0s 133ms/step - loss: 1.6036 - accuracy: 0.5455 - val_loss: 1.3567 - val_accuracy: 0.5747
# Epoch 118/350
# 1/1 [==============================] - 0s 122ms/step - loss: 1.5971 - accuracy: 0.5462 - val_loss: 1.3525 - val_accuracy: 0.5742
# Epoch 119/350
# 1/1 [==============================] - 0s 119ms/step - loss: 1.5972 - accuracy: 0.5455 - val_loss: 1.3472 - val_accuracy: 0.5754
# Epoch 120/350
# 1/1 [==============================] - 0s 119ms/step - loss: 1.5931 - accuracy: 0.5457 - val_loss: 1.3455 - val_accuracy: 0.5775
# Epoch 121/350
# 1/1 [==============================] - 0s 110ms/step - loss: 1.5916 - accuracy: 0.5453 - val_loss: 1.3405 - val_accuracy: 0.5741
# Epoch 122/350
# 1/1 [==============================] - 0s 131ms/step - loss: 1.5916 - accuracy: 0.5468 - val_loss: 1.3443 - val_accuracy: 0.5731
# Epoch 123/350
# 1/1 [==============================] - 0s 103ms/step - loss: 1.5906 - accuracy: 0.5463 - val_loss: 1.3467 - val_accuracy: 0.5807
# Epoch 124/350
# 1/1 [==============================] - 0s 114ms/step - loss: 1.5937 - accuracy: 0.5459 - val_loss: 1.3394 - val_accuracy: 0.5825
# Epoch 125/350
# 1/1 [==============================] - 0s 112ms/step - loss: 1.5834 - accuracy: 0.5468 - val_loss: 1.3282 - val_accuracy: 0.5762
# Epoch 126/350
# 1/1 [==============================] - 0s 114ms/step - loss: 1.5818 - accuracy: 0.5470 - val_loss: 1.3313 - val_accuracy: 0.5760
# Epoch 127/350
# 1/1 [==============================] - 0s 112ms/step - loss: 1.5867 - accuracy: 0.5462 - val_loss: 1.3480 - val_accuracy: 0.5871
# Epoch 128/350
# 1/1 [==============================] - 0s 116ms/step - loss: 1.5903 - accuracy: 0.5457 - val_loss: 1.3428 - val_accuracy: 0.5822
# Epoch 129/350
# 1/1 [==============================] - 0s 126ms/step - loss: 1.5816 - accuracy: 0.5469 - val_loss: 1.3273 - val_accuracy: 0.5766
# Epoch 130/350
# 1/1 [==============================] - 0s 116ms/step - loss: 1.5812 - accuracy: 0.5462 - val_loss: 1.3251 - val_accuracy: 0.5786
# Epoch 131/350
# 1/1 [==============================] - 0s 121ms/step - loss: 1.5744 - accuracy: 0.5475 - val_loss: 1.3334 - val_accuracy: 0.5838
# Epoch 132/350
# 1/1 [==============================] - 0s 123ms/step - loss: 1.5827 - accuracy: 0.5457 - val_loss: 1.3335 - val_accuracy: 0.5813
# Epoch 133/350
# 1/1 [==============================] - 0s 102ms/step - loss: 1.5781 - accuracy: 0.5468 - val_loss: 1.3275 - val_accuracy: 0.5794
# Epoch 134/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.5813 - accuracy: 0.5461 - val_loss: 1.3274 - val_accuracy: 0.5830
# Epoch 135/350
# 1/1 [==============================] - 0s 119ms/step - loss: 1.5713 - accuracy: 0.5477 - val_loss: 1.3257 - val_accuracy: 0.5875
# Epoch 136/350
# 1/1 [==============================] - 0s 117ms/step - loss: 1.5764 - accuracy: 0.5478 - val_loss: 1.3248 - val_accuracy: 0.5912
# Epoch 137/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.5741 - accuracy: 0.5469 - val_loss: 1.3240 - val_accuracy: 0.5908
# Epoch 138/350
# 1/1 [==============================] - 0s 105ms/step - loss: 1.5699 - accuracy: 0.5478 - val_loss: 1.3217 - val_accuracy: 0.5864
# Epoch 139/350
# 1/1 [==============================] - 0s 128ms/step - loss: 1.5741 - accuracy: 0.5470 - val_loss: 1.3219 - val_accuracy: 0.5850
# Epoch 140/350
# 1/1 [==============================] - 0s 133ms/step - loss: 1.5741 - accuracy: 0.5490 - val_loss: 1.3225 - val_accuracy: 0.5847
# Epoch 141/350
# 1/1 [==============================] - 0s 132ms/step - loss: 1.5654 - accuracy: 0.5495 - val_loss: 1.3206 - val_accuracy: 0.5868
# Epoch 142/350
# 1/1 [==============================] - 0s 134ms/step - loss: 1.5660 - accuracy: 0.5487 - val_loss: 1.3180 - val_accuracy: 0.5901
# Epoch 143/350
# 1/1 [==============================] - 0s 106ms/step - loss: 1.5669 - accuracy: 0.5476 - val_loss: 1.3157 - val_accuracy: 0.5919
# Epoch 144/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.5697 - accuracy: 0.5482 - val_loss: 1.3159 - val_accuracy: 0.5937
# Epoch 145/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.5658 - accuracy: 0.5475 - val_loss: 1.3172 - val_accuracy: 0.5922
# Epoch 146/350
# 1/1 [==============================] - 0s 116ms/step - loss: 1.5674 - accuracy: 0.5478 - val_loss: 1.3159 - val_accuracy: 0.5894
# Epoch 147/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.5645 - accuracy: 0.5465 - val_loss: 1.3136 - val_accuracy: 0.5906
# Epoch 148/350
# 1/1 [==============================] - 0s 112ms/step - loss: 1.5653 - accuracy: 0.5488 - val_loss: 1.3123 - val_accuracy: 0.5974
# Epoch 149/350
# 1/1 [==============================] - 0s 127ms/step - loss: 1.5624 - accuracy: 0.5487 - val_loss: 1.3118 - val_accuracy: 0.6023
# Epoch 150/350
# 1/1 [==============================] - 0s 139ms/step - loss: 1.5600 - accuracy: 0.5479 - val_loss: 1.3121 - val_accuracy: 0.5987
# Epoch 151/350
# 1/1 [==============================] - 0s 136ms/step - loss: 1.5600 - accuracy: 0.5489 - val_loss: 1.3135 - val_accuracy: 0.5966
# Epoch 152/350
# 1/1 [==============================] - 0s 138ms/step - loss: 1.5613 - accuracy: 0.5500 - val_loss: 1.3101 - val_accuracy: 0.5913
# Epoch 153/350
# 1/1 [==============================] - 0s 111ms/step - loss: 1.5577 - accuracy: 0.5495 - val_loss: 1.3094 - val_accuracy: 0.5964
# Epoch 154/350
# 1/1 [==============================] - 0s 117ms/step - loss: 1.5603 - accuracy: 0.5479 - val_loss: 1.3118 - val_accuracy: 0.6047
# Epoch 155/350
# 1/1 [==============================] - 0s 103ms/step - loss: 1.5609 - accuracy: 0.5480 - val_loss: 1.3077 - val_accuracy: 0.5994
# Epoch 156/350
# 1/1 [==============================] - 0s 118ms/step - loss: 1.5602 - accuracy: 0.5472 - val_loss: 1.3075 - val_accuracy: 0.5942
# Epoch 157/350
# 1/1 [==============================] - 0s 124ms/step - loss: 1.5597 - accuracy: 0.5464 - val_loss: 1.3185 - val_accuracy: 0.5984
# Epoch 158/350
# 1/1 [==============================] - 0s 108ms/step - loss: 1.5526 - accuracy: 0.5473 - val_loss: 1.3144 - val_accuracy: 0.5946
# Epoch 159/350
# 1/1 [==============================] - 0s 115ms/step - loss: 1.5545 - accuracy: 0.5491 - val_loss: 1.3046 - val_accuracy: 0.5923
# Epoch 160/350
# 1/1 [==============================] - 0s 149ms/step - loss: 1.5515 - accuracy: 0.5479 - val_loss: 1.3058 - val_accuracy: 0.6021
# Epoch 161/350
# 1/1 [==============================] - 0s 162ms/step - loss: 1.5522 - accuracy: 0.5480 - val_loss: 1.3065 - val_accuracy: 0.6039
# Epoch 162/350
# 1/1 [==============================] - 0s 153ms/step - loss: 1.5501 - accuracy: 0.5490 - val_loss: 1.3020 - val_accuracy: 0.6022
# Epoch 163/350
# 1/1 [==============================] - 0s 155ms/step - loss: 1.5518 - accuracy: 0.5467 - val_loss: 1.3012 - val_accuracy: 0.6002
# Epoch 164/350
# 1/1 [==============================] - 0s 162ms/step - loss: 1.5435 - accuracy: 0.5490 - val_loss: 1.3021 - val_accuracy: 0.5964
# Epoch 165/350
# 1/1 [==============================] - 0s 127ms/step - loss: 1.5505 - accuracy: 0.5508 - val_loss: 1.3033 - val_accuracy: 0.6016
# Epoch 166/350
# 1/1 [==============================] - 0s 124ms/step - loss: 1.5481 - accuracy: 0.5493 - val_loss: 1.3026 - val_accuracy: 0.6088
# Epoch 167/350
# 1/1 [==============================] - 0s 128ms/step - loss: 1.5475 - accuracy: 0.5492 - val_loss: 1.3006 - val_accuracy: 0.6113
# Epoch 168/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.5508 - accuracy: 0.5479 - val_loss: 1.3006 - val_accuracy: 0.6035
# Epoch 169/350
# 1/1 [==============================] - 0s 112ms/step - loss: 1.5434 - accuracy: 0.5499 - val_loss: 1.3067 - val_accuracy: 0.5976
# Epoch 170/350
# 1/1 [==============================] - 0s 112ms/step - loss: 1.5453 - accuracy: 0.5490 - val_loss: 1.3097 - val_accuracy: 0.6068
# Epoch 171/350
# 1/1 [==============================] - 0s 112ms/step - loss: 1.5415 - accuracy: 0.5506 - val_loss: 1.3055 - val_accuracy: 0.6099
# Epoch 172/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.5453 - accuracy: 0.5494 - val_loss: 1.2998 - val_accuracy: 0.6020
# Epoch 173/350
# 1/1 [==============================] - 0s 114ms/step - loss: 1.5450 - accuracy: 0.5482 - val_loss: 1.3029 - val_accuracy: 0.6013
# Epoch 174/350
# 1/1 [==============================] - 0s 122ms/step - loss: 1.5388 - accuracy: 0.5495 - val_loss: 1.3087 - val_accuracy: 0.6109
# Epoch 175/350
# 1/1 [==============================] - 0s 125ms/step - loss: 1.5423 - accuracy: 0.5506 - val_loss: 1.3006 - val_accuracy: 0.6111
# Epoch 176/350
# 1/1 [==============================] - 0s 111ms/step - loss: 1.5426 - accuracy: 0.5504 - val_loss: 1.2974 - val_accuracy: 0.6092
# Epoch 177/350
# 1/1 [==============================] - 0s 105ms/step - loss: 1.5419 - accuracy: 0.5485 - val_loss: 1.3042 - val_accuracy: 0.6111
# Epoch 178/350
# 1/1 [==============================] - 0s 112ms/step - loss: 1.5376 - accuracy: 0.5490 - val_loss: 1.3048 - val_accuracy: 0.6119
# Epoch 179/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.5407 - accuracy: 0.5486 - val_loss: 1.2972 - val_accuracy: 0.6082
# Epoch 180/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.5437 - accuracy: 0.5496 - val_loss: 1.2978 - val_accuracy: 0.6072
# Epoch 181/350
# 1/1 [==============================] - 0s 112ms/step - loss: 1.5379 - accuracy: 0.5495 - val_loss: 1.3041 - val_accuracy: 0.6100
# Epoch 182/350
# 1/1 [==============================] - 0s 140ms/step - loss: 1.5340 - accuracy: 0.5514 - val_loss: 1.2947 - val_accuracy: 0.6053
# Epoch 183/350
# 1/1 [==============================] - 0s 148ms/step - loss: 1.5390 - accuracy: 0.5499 - val_loss: 1.2945 - val_accuracy: 0.6034
# Epoch 184/350
# 1/1 [==============================] - 0s 145ms/step - loss: 1.5356 - accuracy: 0.5502 - val_loss: 1.3025 - val_accuracy: 0.6087
# Epoch 185/350
# 1/1 [==============================] - 0s 153ms/step - loss: 1.5361 - accuracy: 0.5502 - val_loss: 1.2991 - val_accuracy: 0.6107
# Epoch 186/350
# 1/1 [==============================] - 0s 153ms/step - loss: 1.5342 - accuracy: 0.5501 - val_loss: 1.2993 - val_accuracy: 0.6089
# Epoch 187/350
# 1/1 [==============================] - 0s 151ms/step - loss: 1.5344 - accuracy: 0.5501 - val_loss: 1.2950 - val_accuracy: 0.6036
# Epoch 188/350
# 1/1 [==============================] - 0s 151ms/step - loss: 1.5346 - accuracy: 0.5486 - val_loss: 1.2954 - val_accuracy: 0.6042
# Epoch 189/350
# 1/1 [==============================] - 0s 136ms/step - loss: 1.5338 - accuracy: 0.5512 - val_loss: 1.3006 - val_accuracy: 0.6123
# Epoch 190/350
# 1/1 [==============================] - 0s 104ms/step - loss: 1.5310 - accuracy: 0.5505 - val_loss: 1.2982 - val_accuracy: 0.6114
# Epoch 191/350
# 1/1 [==============================] - 0s 124ms/step - loss: 1.5322 - accuracy: 0.5513 - val_loss: 1.2948 - val_accuracy: 0.6052
# Epoch 192/350
# 1/1 [==============================] - 0s 126ms/step - loss: 1.5292 - accuracy: 0.5513 - val_loss: 1.2994 - val_accuracy: 0.6047
# Epoch 193/350
# 1/1 [==============================] - 0s 150ms/step - loss: 1.5323 - accuracy: 0.5491 - val_loss: 1.3049 - val_accuracy: 0.6085
# Epoch 194/350
# 1/1 [==============================] - 0s 144ms/step - loss: 1.5331 - accuracy: 0.5502 - val_loss: 1.2985 - val_accuracy: 0.6088
# Epoch 195/350
# 1/1 [==============================] - 0s 125ms/step - loss: 1.5301 - accuracy: 0.5514 - val_loss: 1.2869 - val_accuracy: 0.6075
# Epoch 196/350
# 1/1 [==============================] - 0s 167ms/step - loss: 1.5289 - accuracy: 0.5511 - val_loss: 1.2968 - val_accuracy: 0.6137
# Epoch 197/350
# 1/1 [==============================] - 0s 161ms/step - loss: 1.5228 - accuracy: 0.5518 - val_loss: 1.3024 - val_accuracy: 0.6113
# Epoch 198/350
# 1/1 [==============================] - 0s 149ms/step - loss: 1.5309 - accuracy: 0.5520 - val_loss: 1.2966 - val_accuracy: 0.6064
# Epoch 199/350
# 1/1 [==============================] - 0s 140ms/step - loss: 1.5293 - accuracy: 0.5505 - val_loss: 1.2907 - val_accuracy: 0.6136
# Epoch 200/350
# 1/1 [==============================] - 0s 161ms/step - loss: 1.5237 - accuracy: 0.5513 - val_loss: 1.2899 - val_accuracy: 0.6143
# Epoch 201/350
# 1/1 [==============================] - 0s 122ms/step - loss: 1.5292 - accuracy: 0.5501 - val_loss: 1.3000 - val_accuracy: 0.6139
# Epoch 202/350
# 1/1 [==============================] - 0s 133ms/step - loss: 1.5249 - accuracy: 0.5515 - val_loss: 1.2990 - val_accuracy: 0.6110
# Epoch 203/350
# 1/1 [==============================] - 0s 143ms/step - loss: 1.5247 - accuracy: 0.5517 - val_loss: 1.2908 - val_accuracy: 0.6103
# Epoch 204/350
# 1/1 [==============================] - 0s 146ms/step - loss: 1.5274 - accuracy: 0.5497 - val_loss: 1.2933 - val_accuracy: 0.6124
# Epoch 205/350
# 1/1 [==============================] - 0s 131ms/step - loss: 1.5249 - accuracy: 0.5509 - val_loss: 1.2946 - val_accuracy: 0.6120
# Epoch 206/350
# 1/1 [==============================] - 0s 130ms/step - loss: 1.5236 - accuracy: 0.5500 - val_loss: 1.2983 - val_accuracy: 0.6105
# Epoch 207/350
# 1/1 [==============================] - 0s 123ms/step - loss: 1.5230 - accuracy: 0.5525 - val_loss: 1.3041 - val_accuracy: 0.6116
# Epoch 208/350
# 1/1 [==============================] - 0s 145ms/step - loss: 1.5208 - accuracy: 0.5514 - val_loss: 1.2943 - val_accuracy: 0.6091
# Epoch 209/350
# 1/1 [==============================] - 0s 130ms/step - loss: 1.5183 - accuracy: 0.5536 - val_loss: 1.2896 - val_accuracy: 0.6114
# Epoch 210/350
# 1/1 [==============================] - 0s 122ms/step - loss: 1.5249 - accuracy: 0.5505 - val_loss: 1.2951 - val_accuracy: 0.6136
# Epoch 211/350
# 1/1 [==============================] - 0s 114ms/step - loss: 1.5173 - accuracy: 0.5523 - val_loss: 1.2981 - val_accuracy: 0.6142
# Epoch 212/350
# 1/1 [==============================] - 0s 112ms/step - loss: 1.5166 - accuracy: 0.5526 - val_loss: 1.2919 - val_accuracy: 0.6085
# Epoch 213/350
# 1/1 [==============================] - 0s 119ms/step - loss: 1.5186 - accuracy: 0.5521 - val_loss: 1.2903 - val_accuracy: 0.6110
# Epoch 214/350
# 1/1 [==============================] - 0s 126ms/step - loss: 1.5168 - accuracy: 0.5533 - val_loss: 1.2947 - val_accuracy: 0.6157
# Epoch 215/350
# 1/1 [==============================] - 0s 118ms/step - loss: 1.5147 - accuracy: 0.5530 - val_loss: 1.2999 - val_accuracy: 0.6162
# Epoch 216/350
# 1/1 [==============================] - 0s 127ms/step - loss: 1.5150 - accuracy: 0.5524 - val_loss: 1.2841 - val_accuracy: 0.6167
# Epoch 217/350
# 1/1 [==============================] - 0s 115ms/step - loss: 1.5104 - accuracy: 0.5529 - val_loss: 1.2810 - val_accuracy: 0.6114
# Epoch 218/350
# 1/1 [==============================] - 0s 118ms/step - loss: 1.5126 - accuracy: 0.5545 - val_loss: 1.2937 - val_accuracy: 0.6158
# Epoch 219/350
# 1/1 [==============================] - 0s 119ms/step - loss: 1.5144 - accuracy: 0.5531 - val_loss: 1.3036 - val_accuracy: 0.6138
# Epoch 220/350
# 1/1 [==============================] - 0s 138ms/step - loss: 1.5125 - accuracy: 0.5547 - val_loss: 1.2875 - val_accuracy: 0.6114
# Epoch 221/350
# 1/1 [==============================] - 0s 151ms/step - loss: 1.5114 - accuracy: 0.5537 - val_loss: 1.2805 - val_accuracy: 0.6122
# Epoch 222/350
# 1/1 [==============================] - 0s 129ms/step - loss: 1.5107 - accuracy: 0.5534 - val_loss: 1.2933 - val_accuracy: 0.6187
# Epoch 223/350
# 1/1 [==============================] - 0s 125ms/step - loss: 1.5133 - accuracy: 0.5536 - val_loss: 1.3043 - val_accuracy: 0.6160
# Epoch 224/350
# 1/1 [==============================] - 0s 120ms/step - loss: 1.5125 - accuracy: 0.5533 - val_loss: 1.2851 - val_accuracy: 0.6094
# Epoch 225/350
# 1/1 [==============================] - 0s 122ms/step - loss: 1.5104 - accuracy: 0.5529 - val_loss: 1.2850 - val_accuracy: 0.6081
# Epoch 226/350
# 1/1 [==============================] - 0s 124ms/step - loss: 1.5065 - accuracy: 0.5537 - val_loss: 1.2985 - val_accuracy: 0.6124
# Epoch 227/350
# 1/1 [==============================] - 0s 130ms/step - loss: 1.5074 - accuracy: 0.5535 - val_loss: 1.2914 - val_accuracy: 0.6147
# Epoch 228/350
# 1/1 [==============================] - 0s 109ms/step - loss: 1.5052 - accuracy: 0.5534 - val_loss: 1.2758 - val_accuracy: 0.6153
# Epoch 229/350
# 1/1 [==============================] - 0s 119ms/step - loss: 1.5112 - accuracy: 0.5531 - val_loss: 1.2860 - val_accuracy: 0.6193
# Epoch 230/350
# 1/1 [==============================] - 0s 135ms/step - loss: 1.5082 - accuracy: 0.5531 - val_loss: 1.2995 - val_accuracy: 0.6129
# Epoch 231/350
# 1/1 [==============================] - 0s 145ms/step - loss: 1.5074 - accuracy: 0.5530 - val_loss: 1.2865 - val_accuracy: 0.6128
# Epoch 232/350
# 1/1 [==============================] - 0s 139ms/step - loss: 1.5106 - accuracy: 0.5540 - val_loss: 1.2802 - val_accuracy: 0.6144
# Epoch 233/350
# 1/1 [==============================] - 0s 140ms/step - loss: 1.5119 - accuracy: 0.5527 - val_loss: 1.2905 - val_accuracy: 0.6149
# Epoch 234/350
# 1/1 [==============================] - 0s 137ms/step - loss: 1.5110 - accuracy: 0.5532 - val_loss: 1.3029 - val_accuracy: 0.6127
# Epoch 235/350
# 1/1 [==============================] - 0s 143ms/step - loss: 1.5059 - accuracy: 0.5525 - val_loss: 1.2874 - val_accuracy: 0.6160
# Epoch 236/350
# 1/1 [==============================] - 0s 124ms/step - loss: 1.5071 - accuracy: 0.5538 - val_loss: 1.2765 - val_accuracy: 0.6077
# Epoch 237/350
# 1/1 [==============================] - 0s 139ms/step - loss: 1.5088 - accuracy: 0.5532 - val_loss: 1.2998 - val_accuracy: 0.6119
# Epoch 238/350
# 1/1 [==============================] - 0s 123ms/step - loss: 1.5050 - accuracy: 0.5537 - val_loss: 1.3097 - val_accuracy: 0.6075
# Epoch 239/350
# 1/1 [==============================] - 0s 112ms/step - loss: 1.5063 - accuracy: 0.5534 - val_loss: 1.2780 - val_accuracy: 0.6142
# Epoch 240/350
# 1/1 [==============================] - 0s 117ms/step - loss: 1.5028 - accuracy: 0.5542 - val_loss: 1.2766 - val_accuracy: 0.6129
# Epoch 241/350
# 1/1 [==============================] - 0s 125ms/step - loss: 1.5091 - accuracy: 0.5529 - val_loss: 1.2898 - val_accuracy: 0.6117
# Epoch 242/350
# 1/1 [==============================] - 0s 139ms/step - loss: 1.5039 - accuracy: 0.5553 - val_loss: 1.3000 - val_accuracy: 0.6092
# Epoch 243/350
# 1/1 [==============================] - 0s 139ms/step - loss: 1.5058 - accuracy: 0.5549 - val_loss: 1.2847 - val_accuracy: 0.6152
# Epoch 244/350
# 1/1 [==============================] - 0s 137ms/step - loss: 1.5038 - accuracy: 0.5543 - val_loss: 1.2765 - val_accuracy: 0.6141
# Epoch 245/350
# 1/1 [==============================] - 0s 124ms/step - loss: 1.5021 - accuracy: 0.5540 - val_loss: 1.2793 - val_accuracy: 0.6167
# Epoch 246/350
# 1/1 [==============================] - 0s 119ms/step - loss: 1.5001 - accuracy: 0.5546 - val_loss: 1.2930 - val_accuracy: 0.6108
# Epoch 247/350
# 1/1 [==============================] - 0s 118ms/step - loss: 1.5009 - accuracy: 0.5540 - val_loss: 1.3021 - val_accuracy: 0.6064
# Epoch 248/350
# 1/1 [==============================] - 0s 125ms/step - loss: 1.4992 - accuracy: 0.5556 - val_loss: 1.2908 - val_accuracy: 0.6090
# Epoch 249/350
# 1/1 [==============================] - 0s 129ms/step - loss: 1.5049 - accuracy: 0.5538 - val_loss: 1.2785 - val_accuracy: 0.6138
# Epoch 250/350
# 1/1 [==============================] - 0s 113ms/step - loss: 1.4996 - accuracy: 0.5542 - val_loss: 1.2882 - val_accuracy: 0.6153
# Epoch 251/350
# 1/1 [==============================] - 0s 119ms/step - loss: 1.4958 - accuracy: 0.5565 - val_loss: 1.2925 - val_accuracy: 0.6143
# Epoch 252/350
# 1/1 [==============================] - 0s 123ms/step - loss: 1.4947 - accuracy: 0.5547 - val_loss: 1.2875 - val_accuracy: 0.6129
# Epoch 253/350
# 1/1 [==============================] - 0s 122ms/step - loss: 1.4929 - accuracy: 0.5552 - val_loss: 1.2806 - val_accuracy: 0.6112
# Epoch 254/350
# 1/1 [==============================] - 0s 104ms/step - loss: 1.4965 - accuracy: 0.5540 - val_loss: 1.2894 - val_accuracy: 0.6073
# Epoch 255/350
# 1/1 [==============================] - 0s 111ms/step - loss: 1.4952 - accuracy: 0.5566 - val_loss: 1.2953 - val_accuracy: 0.6061
# Epoch 256/350
# 1/1 [==============================] - 0s 117ms/step - loss: 1.4978 - accuracy: 0.5547 - val_loss: 1.2866 - val_accuracy: 0.6106
# Epoch 257/350
# 1/1 [==============================] - 0s 125ms/step - loss: 1.4914 - accuracy: 0.5550 - val_loss: 1.2747 - val_accuracy: 0.6131
# Epoch 258/350
# 1/1 [==============================] - 0s 116ms/step - loss: 1.4903 - accuracy: 0.5560 - val_loss: 1.2863 - val_accuracy: 0.6122
# Epoch 259/350
# 1/1 [==============================] - 0s 119ms/step - loss: 1.4947 - accuracy: 0.5545 - val_loss: 1.3035 - val_accuracy: 0.6066
# Epoch 260/350
# 1/1 [==============================] - 0s 119ms/step - loss: 1.4963 - accuracy: 0.5552 - val_loss: 1.2935 - val_accuracy: 0.6064
# Epoch 261/350
# 1/1 [==============================] - 0s 122ms/step - loss: 1.4970 - accuracy: 0.5534 - val_loss: 1.2753 - val_accuracy: 0.6097
# Epoch 262/350
# 1/1 [==============================] - 0s 116ms/step - loss: 1.4962 - accuracy: 0.5548 - val_loss: 1.2841 - val_accuracy: 0.6092
# Epoch 263/350
# 1/1 [==============================] - 0s 117ms/step - loss: 1.4815 - accuracy: 0.5565 - val_loss: 1.2973 - val_accuracy: 0.6041
# Epoch 264/350
# 1/1 [==============================] - 0s 121ms/step - loss: 1.4970 - accuracy: 0.5542 - val_loss: 1.2897 - val_accuracy: 0.6097
# Epoch 265/350
# 1/1 [==============================] - 0s 123ms/step - loss: 1.4982 - accuracy: 0.5552 - val_loss: 1.2734 - val_accuracy: 0.6142
# Epoch 266/350
# 1/1 [==============================] - 0s 130ms/step - loss: 1.4892 - accuracy: 0.5558 - val_loss: 1.2885 - val_accuracy: 0.6098
# Epoch 267/350
# 1/1 [==============================] - 0s 119ms/step - loss: 1.4926 - accuracy: 0.5542 - val_loss: 1.3018 - val_accuracy: 0.6065
# Epoch 268/350
# 1/1 [==============================] - 0s 108ms/step - loss: 1.4900 - accuracy: 0.5570 - val_loss: 1.2865 - val_accuracy: 0.6062
# Epoch 269/350
# 1/1 [==============================] - 0s 116ms/step - loss: 1.4934 - accuracy: 0.5564 - val_loss: 1.2749 - val_accuracy: 0.6100
# Epoch 270/350
# 1/1 [==============================] - 0s 125ms/step - loss: 1.4908 - accuracy: 0.5560 - val_loss: 1.2840 - val_accuracy: 0.6116
# Epoch 271/350
# 1/1 [==============================] - 0s 121ms/step - loss: 1.4913 - accuracy: 0.5562 - val_loss: 1.2857 - val_accuracy: 0.6084
# Epoch 272/350
# 1/1 [==============================] - 0s 132ms/step - loss: 1.4867 - accuracy: 0.5569 - val_loss: 1.2808 - val_accuracy: 0.6089
# Epoch 273/350
# 1/1 [==============================] - 0s 119ms/step - loss: 1.4937 - accuracy: 0.5557 - val_loss: 1.2851 - val_accuracy: 0.6096
# Epoch 274/350
# 1/1 [==============================] - 0s 124ms/step - loss: 1.4887 - accuracy: 0.5565 - val_loss: 1.2873 - val_accuracy: 0.6057
# Epoch 275/350
# 1/1 [==============================] - 0s 122ms/step - loss: 1.4890 - accuracy: 0.5553 - val_loss: 1.2938 - val_accuracy: 0.6051
# Epoch 276/350
# 1/1 [==============================] - 0s 128ms/step - loss: 1.4852 - accuracy: 0.5578 - val_loss: 1.2870 - val_accuracy: 0.6096
# Epoch 277/350
# 1/1 [==============================] - 0s 123ms/step - loss: 1.4892 - accuracy: 0.5590 - val_loss: 1.2738 - val_accuracy: 0.6114
# Epoch 278/350
# 1/1 [==============================] - 0s 125ms/step - loss: 1.4876 - accuracy: 0.5557 - val_loss: 1.2824 - val_accuracy: 0.6066
# Epoch 279/350
# 1/1 [==============================] - 0s 147ms/step - loss: 1.4816 - accuracy: 0.5560 - val_loss: 1.2974 - val_accuracy: 0.6042
# Epoch 280/350
# 1/1 [==============================] - 0s 132ms/step - loss: 1.4874 - accuracy: 0.5553 - val_loss: 1.2743 - val_accuracy: 0.6096
# Epoch 281/350
# 1/1 [==============================] - 0s 117ms/step - loss: 1.4837 - accuracy: 0.5572 - val_loss: 1.2761 - val_accuracy: 0.6131
# Epoch 282/350
# 1/1 [==============================] - 0s 118ms/step - loss: 1.4859 - accuracy: 0.5572 - val_loss: 1.2975 - val_accuracy: 0.6075
# Epoch 283/350
# 1/1 [==============================] - 0s 117ms/step - loss: 1.4924 - accuracy: 0.5538 - val_loss: 1.2842 - val_accuracy: 0.6103
# Epoch 284/350
# 1/1 [==============================] - 0s 127ms/step - loss: 1.4817 - accuracy: 0.5570 - val_loss: 1.2818 - val_accuracy: 0.6091
# Epoch 285/350
# 1/1 [==============================] - 0s 139ms/step - loss: 1.4900 - accuracy: 0.5561 - val_loss: 1.2883 - val_accuracy: 0.6084
# Epoch 286/350
# 1/1 [==============================] - 0s 124ms/step - loss: 1.4841 - accuracy: 0.5572 - val_loss: 1.2857 - val_accuracy: 0.6071
# Epoch 287/350
# 1/1 [==============================] - 0s 129ms/step - loss: 1.4861 - accuracy: 0.5554 - val_loss: 1.2815 - val_accuracy: 0.6096
# Epoch 288/350
# 1/1 [==============================] - 0s 106ms/step - loss: 1.4879 - accuracy: 0.5557 - val_loss: 1.2884 - val_accuracy: 0.6097
# Epoch 289/350
# 1/1 [==============================] - 0s 121ms/step - loss: 1.4827 - accuracy: 0.5562 - val_loss: 1.2830 - val_accuracy: 0.6119
# Epoch 290/350
# 1/1 [==============================] - 0s 124ms/step - loss: 1.4817 - accuracy: 0.5573 - val_loss: 1.2795 - val_accuracy: 0.6104
# Epoch 291/350
# 1/1 [==============================] - 0s 117ms/step - loss: 1.4785 - accuracy: 0.5573 - val_loss: 1.2832 - val_accuracy: 0.6086
# Epoch 292/350
# 1/1 [==============================] - 0s 120ms/step - loss: 1.4757 - accuracy: 0.5593 - val_loss: 1.2824 - val_accuracy: 0.6084
# Epoch 293/350
# 1/1 [==============================] - 0s 127ms/step - loss: 1.4848 - accuracy: 0.5566 - val_loss: 1.2806 - val_accuracy: 0.6065
# Epoch 294/350
# 1/1 [==============================] - 0s 125ms/step - loss: 1.4786 - accuracy: 0.5585 - val_loss: 1.2839 - val_accuracy: 0.6061
# Epoch 295/350
# 1/1 [==============================] - 0s 125ms/step - loss: 1.4819 - accuracy: 0.5573 - val_loss: 1.2813 - val_accuracy: 0.6102
# Epoch 296/350
# 1/1 [==============================] - 0s 112ms/step - loss: 1.4771 - accuracy: 0.5587 - val_loss: 1.2781 - val_accuracy: 0.6098
# Epoch 297/350
# 1/1 [==============================] - 0s 118ms/step - loss: 1.4819 - accuracy: 0.5570 - val_loss: 1.2839 - val_accuracy: 0.6070
# Epoch 298/350
# 1/1 [==============================] - 0s 126ms/step - loss: 1.4746 - accuracy: 0.5582 - val_loss: 1.2793 - val_accuracy: 0.6091
# Epoch 299/350
# 1/1 [==============================] - 0s 120ms/step - loss: 1.4781 - accuracy: 0.5567 - val_loss: 1.2848 - val_accuracy: 0.6071
# Epoch 300/350
# 1/1 [==============================] - 0s 116ms/step - loss: 1.4824 - accuracy: 0.5580 - val_loss: 1.2803 - val_accuracy: 0.6068
# Epoch 301/350
# 1/1 [==============================] - 0s 122ms/step - loss: 1.4828 - accuracy: 0.5569 - val_loss: 1.2750 - val_accuracy: 0.6073
# Epoch 302/350
# 1/1 [==============================] - 0s 124ms/step - loss: 1.4833 - accuracy: 0.5578 - val_loss: 1.2763 - val_accuracy: 0.6107
# Epoch 303/350
# 1/1 [==============================] - 0s 125ms/step - loss: 1.4775 - accuracy: 0.5581 - val_loss: 1.2835 - val_accuracy: 0.6092
# Epoch 304/350
# 1/1 [==============================] - ETA: 0s - loss: 1.4759 - accuracy: 0.5577Restoring model weights from the end of the best epoch: 229.
# 1/1 [==============================] - 0s 122ms/step - loss: 1.4759 - accuracy: 0.5577 - val_loss: 1.2841 - val_accuracy: 0.6066
# Epoch 304: early stopping

# %%
# View two graphs to see how accuracy and error evolve during the training process

# Visualize the evolution of the network accuracy
plt.plot(gcn_history.history['accuracy'])
plt.plot(gcn_history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Entrenament', 'Validació'], loc='upper right')
plt.show()

# Visualize the evolution of the network error
plt.plot(gcn_history.history['loss'])
plt.plot(gcn_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Entrenament', 'Validació'], loc='upper right')
plt.show()

# %%
# View two graphs to see how accuracy and error evolve during the training process
utils.plot_history(gcn_history)

# %%
# Evaluate model performance on Validation Set
val_metrics = gcn_model.evaluate(val_gen)
print("\nValidatiom Set Metrics:")

for name, value in zip(gcn_model.metrics_names, val_metrics):
    print("\t{}: {:0.4f}".format(name, value))
# Out:
# 1/1 [==============================] - 0s 58ms/step - loss: 1.2860 - accuracy: 0.6193
#
# Validatiom Set Metrics:
# 	loss: 1.2860
# 	accuracy: 0.6193

# %%
from keras.models import load_model
from stellargraph.layer.gcn import GraphConvolution
from stellargraph.layer.misc import GatherIndices, SqueezedSparseConversion

# Save the model
gcn_model.save(os.path.join(models_dir, 'gcn_model_7_features.h5'))

# Load the model
gcn_model = load_model(os.path.join(models_dir,'gcn_model_7_features.h5'), custom_objects={
    'GraphConvolution': GraphConvolution, 
    'GatherIndices': GatherIndices, 
    'SqueezedSparseConversion': SqueezedSparseConversion
})

# %% [markdown]
# ## Making predictions with the model

# %% [markdown]
# **Validation Set**

# %%
# Make predictions on Validation Set
val_gen = generator.flow(val.node_id)
val_predictions = gcn_model.predict(val_gen)

# %%
# Convert one-hot-encoding label to Text label
val_node_predictions = target_encoding.inverse_transform(val_predictions.squeeze())

val['node_prediction'] = val_node_predictions

val.tail(10)
# Out:
#                             node_id              node_target node_prediction
# id
# 137445  naturedecouvertes217_137445                    OTHER           OTHER
# 137446  naturedecouvertes217_137446                    OTHER           OTHER
# 137447  naturedecouvertes217_137447             SUPPLIER_VAT           OTHER
# 137449  naturedecouvertes217_137449                    OTHER           OTHER
# 137450  naturedecouvertes217_137450                    OTHER           OTHER
# 137451  naturedecouvertes217_137451                    OTHER           OTHER
# 137452  naturedecouvertes217_137452      SUPPLIER_FAX_NUMBER           OTHER
# 137453  naturedecouvertes217_137453                    OTHER           OTHER
# 137454  naturedecouvertes217_137454                    OTHER           OTHER
# 137455  naturedecouvertes217_137455  SUPPLIER_CONTACT_NUMBER           OTHER

# %%
# Compute frequency on each one of classes for class attribute 'node_target'
val["node_target"].value_counts()
# Out:
# OTHER                              73444
# PRODUCT_DESCRIPTION                11394
# SUPPLIER_ADDRESS                    6985
# BILLING_ADDRESS                     4623
# SHIPPING_ADDRESS                    4524
# INVOICE_DATE                        2790
# SUPPLIER_VAT                        2779
# SUPPLIER_NAME                       2707
# PRODUCT_TOTAL_PRICE_WITHOUT_TAX     2470
# UNIT_PRICE                          2251
# SUPPLIER_CONTACT_NUMBER             2188
# SUPPLIER_FAX_NUMBER                 1835
# QUANTITY                            1762
# SHIPPING_NAME                       1656
# BILLING_NAME                        1654
# TOTAL_AMOUNT                        1602
# TAX_RATE                            1409
# TOTAL_TAX                           1254
# SNO                                 1203
# SUPPLIER_SIRET                      1006
# TOTAL_WITHOUT_TAX                    980
# INVOICE_NUMBER                       930
# ORDER_NUMBER                         700
# SUPPLIER_ID                          548
# PRODUCT_TOTAL                        543
# PRODUCT_TOTAL_PRICE_WITH_TAX         434
# PAYMENT_MODE                         430
# CLIENT_NUMBER                        300
# IMAGE                                200
# Name: node_target, dtype: int64

# %%
# Compute frequency on each one of classes for class attribute 'node_prediction'
val["node_prediction"].value_counts()
# Out:
# OTHER                              107951
# PRODUCT_DESCRIPTION                 12732
# BILLING_ADDRESS                      6174
# SHIPPING_ADDRESS                     3056
# SUPPLIER_ADDRESS                     1400
# SUPPLIER_CONTACT_NUMBER              1309
# PRODUCT_TOTAL_PRICE_WITHOUT_TAX       994
# SUPPLIER_VAT                          549
# INVOICE_DATE                          248
# SNO                                   135
# SUPPLIER_FAX_NUMBER                    53
# Name: node_prediction, dtype: int64

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Calculate some metrics: precision, recall i f1-score by class on Validation Set.
print('\n Mètriques precision, recall i f1-score obtingudes per classe')
print(classification_report(val.node_target, val_node_predictions))
# Out:
#  Mètriques precision, recall i f1-score obtingudes per classe
# C:\Users\Albert\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Albert\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                  precision    recall  f1-score   support
#
#                 BILLING_ADDRESS       0.48      0.64      0.55      4623
#                    BILLING_NAME       0.00      0.00      0.00      1654
#                   CLIENT_NUMBER       0.00      0.00      0.00       300
#                           IMAGE       0.00      0.00      0.00       200
#                    INVOICE_DATE       0.69      0.06      0.11      2790
#                  INVOICE_NUMBER       0.00      0.00      0.00       930
#                    ORDER_NUMBER       0.00      0.00      0.00       700
#                           OTHER       0.63      0.93      0.75     73444
#                    PAYMENT_MODE       0.00      0.00      0.00       430
#             PRODUCT_DESCRIPTION       0.63      0.70      0.66     11394
#                   PRODUCT_TOTAL       0.00      0.00      0.00       543
# PRODUCT_TOTAL_PRICE_WITHOUT_TAX       0.30      0.12      0.17      2470
#    PRODUCT_TOTAL_PRICE_WITH_TAX       0.00      0.00      0.00       434
#                        QUANTITY       0.00      0.00      0.00      1762
#                SHIPPING_ADDRESS       0.53      0.36      0.43      4524
#                   SHIPPING_NAME       0.00      0.00      0.00      1656
#                             SNO       0.83      0.09      0.17      1203
#                SUPPLIER_ADDRESS       0.64      0.13      0.21      6985
#         SUPPLIER_CONTACT_NUMBER       0.56      0.33      0.42      2188
#             SUPPLIER_FAX_NUMBER       0.91      0.03      0.05      1835
#                     SUPPLIER_ID       0.00      0.00      0.00       548
#                   SUPPLIER_NAME       0.00      0.00      0.00      2707
#                  SUPPLIER_SIRET       0.00      0.00      0.00      1006
#                    SUPPLIER_VAT       0.76      0.15      0.25      2779
#                        TAX_RATE       0.00      0.00      0.00      1409
#                    TOTAL_AMOUNT       0.00      0.00      0.00      1602
#                       TOTAL_TAX       0.00      0.00      0.00      1254
#               TOTAL_WITHOUT_TAX       0.00      0.00      0.00       980
#                      UNIT_PRICE       0.00      0.00      0.00      2251
#
#                        accuracy                           0.62    134601
#                       macro avg       0.24      0.12      0.13    134601
#                    weighted avg       0.53      0.62      0.53    134601
# C:\Users\Albert\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Visualize confusion matrix
print('\nMatriu de confusió')
matrix = confusion_matrix(val.node_target, val_node_predictions)

targets = target_encoding.classes_

plt.figure(figsize=(15, 15))
ax = sns.heatmap(matrix, annot=True, fmt="d", cmap='Blues', square=True)
ax.set_xticklabels(targets, rotation = 90, size = 10)
ax.set_yticklabels(targets, rotation = 0, size = 10)
plt.xlabel("Predicció")
plt.ylabel("Real")
# Out:
# Matriu de confusió
# Text(114.0, 0.5, 'Real')

# %% [markdown]
# **Test Set**

# %%
# Evaluate model performance on Test Set
test_gen = generator.flow(test.node_id, test_targets)

test_metrics = gcn_model.evaluate(test_gen)

print("\nTest Set Metrics:")

for name, val in zip(gcn_model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
# 1/1 [==============================] - 0s 347ms/step - loss: 1.2898 - accuracy: 0.6178
#
# Test Set Metrics:
# 	loss: 1.2898
# 	accuracy: 0.6178

# %%
test_gen = generator.flow(test.node_id)
test_predictions = gcn_model.predict(test_gen)

# Convert one-hot-encoding label to Text label
test_node_predictions = target_encoding.inverse_transform(test_predictions.squeeze())

test['node_prediction'] = test_node_predictions

test.head(10)
# Out:
#              node_id       node_target node_prediction
# id
# 62801  darty77_62801     SUPPLIER_NAME           OTHER
# 62802  darty77_62802     SUPPLIER_NAME           OTHER
# 62803  darty77_62803     SUPPLIER_NAME           OTHER
# 62828  darty77_62828     SHIPPING_NAME           OTHER
# 62829  darty77_62829     SHIPPING_NAME           OTHER
# 62804  darty77_62804             OTHER           OTHER
# 62805  darty77_62805             OTHER           OTHER
# 62830  darty77_62830  SHIPPING_ADDRESS           OTHER
# 62831  darty77_62831  SHIPPING_ADDRESS           OTHER
# 62832  darty77_62832  SHIPPING_ADDRESS           OTHER

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Calculate some metrics: precision, recall i f1-score by class on Test Set.
print('\n Mètriques precision, recall i f1-score obtingudes per classe')
print(classification_report(test.node_target, test_node_predictions))
# Out:
#  Mètriques precision, recall i f1-score obtingudes per classe
# C:\Users\Albert\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Albert\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                  precision    recall  f1-score   support
#
#                 BILLING_ADDRESS       0.47      0.63      0.54      2294
#                    BILLING_NAME       0.00      0.00      0.00       813
#                   CLIENT_NUMBER       0.00      0.00      0.00       150
#                           IMAGE       0.00      0.00      0.00       100
#                    INVOICE_DATE       0.68      0.07      0.13      1392
#                  INVOICE_NUMBER       0.00      0.00      0.00       468
#                    ORDER_NUMBER       0.00      0.00      0.00       350
#                           OTHER       0.63      0.93      0.75     36887
#                    PAYMENT_MODE       0.00      0.00      0.00       215
#             PRODUCT_DESCRIPTION       0.63      0.69      0.66      5969
#                   PRODUCT_TOTAL       0.00      0.00      0.00       278
# PRODUCT_TOTAL_PRICE_WITHOUT_TAX       0.27      0.13      0.17      1276
#    PRODUCT_TOTAL_PRICE_WITH_TAX       0.00      0.00      0.00       223
#                        QUANTITY       0.00      0.00      0.00       904
#                SHIPPING_ADDRESS       0.55      0.36      0.44      2261
#                   SHIPPING_NAME       0.00      0.00      0.00       813
#                             SNO       0.88      0.12      0.21       627
#                SUPPLIER_ADDRESS       0.64      0.13      0.22      3499
#         SUPPLIER_CONTACT_NUMBER       0.58      0.38      0.46      1192
#             SUPPLIER_FAX_NUMBER       1.00      0.03      0.05       982
#                     SUPPLIER_ID       0.00      0.00      0.00       312
#                   SUPPLIER_NAME       0.00      0.00      0.00      1331
#                  SUPPLIER_SIRET       0.00      0.00      0.00       515
#                    SUPPLIER_VAT       0.82      0.15      0.26      1429
#                        TAX_RATE       0.00      0.00      0.00       730
#                    TOTAL_AMOUNT       0.00      0.00      0.00       810
#                       TOTAL_TAX       0.00      0.00      0.00       622
#               TOTAL_WITHOUT_TAX       0.00      0.00      0.00       491
#                      UNIT_PRICE       0.00      0.00      0.00      1146
#
#                        accuracy                           0.62     68079
#                       macro avg       0.25      0.12      0.13     68079
#                    weighted avg       0.53      0.62      0.53     68079
# C:\Users\Albert\AppData\Roaming\Python\Python37\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Visualize confusion matrix
print('\nMatriu de confusió')
matrix = confusion_matrix(test.node_target, test_node_predictions)

targets = target_encoding.classes_

plt.figure(figsize=(15, 15))
ax = sns.heatmap(matrix, annot=True, fmt="d", cmap='Blues', square=True)
ax.set_xticklabels(targets, rotation = 90, size = 10)
ax.set_yticklabels(targets, rotation = 0, size = 10)
plt.xlabel("Predicció")
plt.ylabel("Real")
# Out:
# Matriu de confusió
# Text(114.0, 0.5, 'Real')
